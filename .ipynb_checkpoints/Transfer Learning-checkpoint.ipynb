# %% [markdown]
# # Setup and Imports

# %%
import prepare_MRI_images as pmi
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, BatchNormalization, Dropout
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.optimizers import adam_v2, rmsprop_v2
from keras.optimizers import gradient_descent_v2
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import ParameterSampler
from scipy.stats import reciprocal
from sklearn.metrics import confusion_matrix

from keras.applications import vgg16, xception, ResNet50V2, InceptionResNetV2, EfficientNetB7

# %% [markdown]
# # Get the Data

# %%
no_tumor_path = 'brain-mri-images-for-brain-tumor-detection/no'
tumor_path = 'brain-mri-images-for-brain-tumor-detection/yes'
width = 256
height = 256
color = 'RGB'
num_no_tumors = len(os.listdir(no_tumor_path))
num_tumors = len(os.listdir(tumor_path))

X, y = pmi.clean_MRI_scans(no_tumor_path, tumor_path, width, height, color, num_no_tumors, num_tumors)

# %%
print(X.shape)
print(y.shape)
# Out:
# (253, 256, 256, 3)
# (253,)

# %% [markdown]
# # Split the Data into Training and Test Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state=42, stratify=y) 
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .25, random_state=42, stratify=y_train)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (151, 256, 256, 3)
# (51, 256, 256, 3)
# (51, 256, 256, 3)
# (151,)
# (51,)
# (51,)

# %%
datagen = ImageDataGenerator(
    rotation_range = 15,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    horizontal_flip = True,
)
datagen.fit(X_train)

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## VGG16 Architecture

# %%
vgg16_model = vgg16.VGG16(weights = 'imagenet', include_top = False, input_shape = (256, 256, 3), pooling = 'avg')

# %%
for layer in vgg16_model.layers[:-5]:
    layer.trainable = False

# %%
last_output = vgg16_model.output

x = Dense(2, activation = 'softmax')(last_output)

new_vgg16_model = Model(inputs = vgg16_model.input, outputs = x)

new_vgg16_model.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_11 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 14,715,714
# Trainable params: 7,080,450
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
new_vgg16_model.compile(optimizer = adam_v2.Adam(learning_rate = 0.0001), 
                        loss = 'sparse_categorical_crossentropy', metrics = ["accuracy"])

# %%
early = EarlyStopping(monitor = 'val_loss', patience = 5)
vgg_history = new_vgg16_model.fit(datagen.flow(X_train, y_train, batch_size = 32),
                       epochs = 100, verbose = 0, validation_data = (X_val, y_val),
                       callbacks = [early])

# %%
plt.figure(figsize = (12,8))
plt.plot(vgg_history.history['accuracy'], label='train')
plt.plot(vgg_history.history['val_accuracy'], label='val')
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy During Training with Early Stoppping")
plt.legend()
plt.show()

# %% [markdown]
# ## Xception Architecture

# %%
xception_model = xception.Xception(weights = 'imagenet', include_top = False, input_shape = (256, 256, 3), pooling = 'avg')

# %%
for layer in xception_model.layers[:-5]:
    layer.trainable = False

# %%
last_output = xception_model.output

x = Dense(2, activation = 'softmax')(last_output)

new_xception_model = Model(inputs = xception_model.input, outputs = x)

# %%
new_xception_model.compile(optimizer = adam_v2.Adam(learning_rate = 0.0001), 
                        loss = 'sparse_categorical_crossentropy', metrics = ["accuracy"])

# %%
early = EarlyStopping(monitor = 'val_loss', patience = 5)
xception_history = new_xception_model.fit(datagen.flow(X_train, y_train, batch_size = 32),
                       epochs = 100, verbose = 0, validation_data = (X_val, y_val),
                       callbacks = [early])

# %%
plt.figure(figsize = (12,8))
plt.plot(xception_history.history['accuracy'], label='train')
plt.plot(xception_history.history['val_accuracy'], label='val')
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy During Training with Early Stoppping")
plt.legend()
plt.show()

# %% [markdown]
# ## ResNet Architecture

# %%
resnet_model = ResNet50V2(weights = 'imagenet', include_top = False, input_shape = (256, 256, 3), pooling = 'avg')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 13s 0us/step

# %%
for layer in resnet_model.layers[:-5]:
    layer.trainable = False

# %%
last_output = resnet_model.output

x = Dense(2, activation = 'softmax')(last_output)

new_resnet_model = Model(inputs = resnet_model.input, outputs = x)

# %%
new_resnet_model.compile(optimizer = adam_v2.Adam(learning_rate = 0.0001), 
                        loss = 'sparse_categorical_crossentropy', metrics = ["accuracy"])

# %%
early = EarlyStopping(monitor = 'val_loss', patience = 5)
resnet_history = new_resnet_model.fit(datagen.flow(X_train, y_train, batch_size = 32),
                       epochs = 100, verbose = 0, validation_data = (X_val, y_val),
                       callbacks = [early])

# %%
plt.figure(figsize = (12,8))
plt.plot(resnet_history.history['accuracy'], label='train')
plt.plot(resnet_history.history['val_accuracy'], label='val')
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy During Training with Early Stoppping")
plt.legend()
plt.show()

# %% [markdown]
# ## Inception ResNet Architecture

# %%
inception_res_model = InceptionResNetV2(weights = 'imagenet', include_top = False, 
                                                     input_shape = (256, 256, 3), pooling = 'avg')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 32s 0us/step

# %%
for layer in inception_res_model.layers[:-5]:
    layer.trainable = False

# %%
last_output = inception_res_model.output

x = Dense(2, activation = 'softmax')(last_output)

new_inception_res_model = Model(inputs = inception_res_model.input, outputs = x)

# %%
new_inception_res_model.compile(optimizer = adam_v2.Adam(learning_rate = 0.0001), 
                        loss = 'sparse_categorical_crossentropy', metrics = ["accuracy"])

# %%
early = EarlyStopping(monitor = 'val_loss', patience = 5)
inception_res_history = new_inception_res_model.fit(datagen.flow(X_train, y_train, batch_size = 32),
                       epochs = 100, verbose = 0, validation_data = (X_val, y_val),
                       callbacks = [early])

# %%
plt.figure(figsize = (12,8))
plt.plot(inception_res_history.history['accuracy'], label='train')
plt.plot(inception_res_history.history['val_accuracy'], label='val')
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy During Training with Early Stoppping")
plt.legend()
plt.show()

# %% [markdown]
# ## EfficientNet Architecture

# %%
efficientnet_model = EfficientNetB7(weights = 'imagenet', include_top = False, 
                                               input_shape = (256, 256, 3), pooling = 'avg')

# %%
for layer in efficientnet_model.layers[:-5]:
    layer.trainable = False

# %%
last_output = efficientnet_model.output

x = Dense(2, activation = 'softmax')(last_output)

new_efficientnet_model = Model(inputs = efficientnet_model.input, outputs = x)

# %%
new_efficientnet_model.compile(optimizer = adam_v2.Adam(learning_rate = 0.0001), 
                        loss = 'sparse_categorical_crossentropy', metrics = ["accuracy"])

# %%
early = EarlyStopping(monitor = 'val_loss', patience = 5)
efficientnet_history = new_efficientnet_model.fit(datagen.flow(X_train, y_train, batch_size = 32),
                       epochs = 100, verbose = 0, validation_data = (X_val, y_val),
                       callbacks = [early])

# %%
plt.figure(figsize = (12,8))
plt.plot(efficientnet_history.history['accuracy'], label='train')
plt.plot(efficientnet_history.history['val_accuracy'], label='val')
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy During Training with Early Stoppping")
plt.legend()
plt.show()

# %% [markdown]
# # Test Results

# %%
def plot_confusion_matrix(test_labels, prediction_labels):
    cm_labels = ['0', '1']
    cm = confusion_matrix(test_labels, prediction_labels)
    plt.figure(figsize=(14,6))
    plt.imshow(cm, cmap=plt.cm.Blues)
    plt.colorbar()
    indexes = np.arange(len(cm_labels))
    for i in indexes:
        for j in indexes:
            plt.text(j, i, cm[i, j])
    plt.xticks(indexes, cm_labels)
    plt.xlabel('Predicted Label')
    plt.yticks(indexes, cm_labels)
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# ## VGG16 Architecture

# %%
vgg16_score = new_vgg16_model.evaluate(X_test, y_test, batch_size = 32, verbose = 0)
vgg16_test_acc = vgg16_score[1] * 100
print(f'VGG16 Model Test Accuracy: {vgg16_test_acc:.2f}%')
# Out:
# VGG16 Model Test Accuracy: 90.20%

# %%
y_pred = np.argmax(new_vgg16_model.predict(X_test, verbose = 0), axis = 1)
plot_confusion_matrix(test_labels=y_test, prediction_labels=y_pred)

# %% [markdown]
# ## Xception Architecture

# %%
xception_score = new_xception_model.evaluate(X_test, y_test, batch_size = 32, verbose = 0)
xception_test_acc = xception_score[1] * 100
print(f'Xception Model Test Accuracy: {xception_test_acc:.2f}%')
# Out:
# Xception Model Test Accuracy: 90.20%

# %%
y_pred = np.argmax(new_xception_model.predict(X_test, verbose = 0), axis = 1)
plot_confusion_matrix(test_labels=y_test, prediction_labels=y_pred)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001CB3D2B9280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ## ResNet Architecture

# %%
resent_score = new_resnet_model.evaluate(X_test, y_test, batch_size = 32, verbose = 0)
resnet_test_acc = resent_score[1] * 100
print(f'ResNet Model Test Accuracy: {resnet_test_acc:.2f}%')
# Out:
# ResNet Model Test Accuracy: 92.16%

# %%
y_pred = np.argmax(new_resnet_model.predict(X_test, verbose = 0), axis = 1)
plot_confusion_matrix(test_labels=y_test, prediction_labels=y_pred)

# %% [markdown]
# ## Inception ResNet Architecture

# %%
inception_res_score = new_inception_res_model.evaluate(X_test, y_test, batch_size = 32, verbose = 0)
inres_test_acc = inception_res_score[1] * 100
print(f'Inception ResNet Model Test Accuracy: {inres_test_acc:.2f}%')
# Out:
# Inception ResNet Model Test Accuracy: 86.27%

# %%
y_pred = np.argmax(new_inception_res_model.predict(X_test, verbose = 0), axis = 1)
plot_confusion_matrix(test_labels=y_test, prediction_labels=y_pred)

# %% [markdown]
# ## EfficientNet Architecture

# %%
efficient_score = new_efficientnet_model.evaluate(X_test, y_test, batch_size = 32, verbose = 0)
efficient_test_acc = efficient_score[1] * 100
print(f'EfficientNet Model Test Accuracy: {efficient_test_acc:.2f}%')
# Out:
# EfficientNet Model Test Accuracy: 60.78%

# %%
y_pred = np.argmax(new_efficientnet_model.predict(X_test, verbose = 0), axis = 1)
plot_confusion_matrix(test_labels=y_test, prediction_labels=y_pred)
